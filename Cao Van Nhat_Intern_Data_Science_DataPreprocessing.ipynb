# %%
import pandas as pd
import numpy as np

# %%
df_styles = pd.read_csv(r'E:\Dataset\fashion-dataset\styles.csv', error_bad_lines = False)
# Out:
# b'Skipping line 6044: expected 10 fields, saw 11\nSkipping line 6569: expected 10 fields, saw 11\nSkipping line 7399: expected 10 fields, saw 11\nSkipping line 7939: expected 10 fields, saw 11\nSkipping line 9026: expected 10 fields, saw 11\nSkipping line 10264: expected 10 fields, saw 11\nSkipping line 10427: expected 10 fields, saw 11\nSkipping line 10905: expected 10 fields, saw 11\nSkipping line 11373: expected 10 fields, saw 11\nSkipping line 11945: expected 10 fields, saw 11\nSkipping line 14112: expected 10 fields, saw 11\nSkipping line 14532: expected 10 fields, saw 11\nSkipping line 15076: expected 10 fields, saw 12\nSkipping line 29906: expected 10 fields, saw 11\nSkipping line 31625: expected 10 fields, saw 11\nSkipping line 33020: expected 10 fields, saw 11\nSkipping line 35748: expected 10 fields, saw 11\nSkipping line 35962: expected 10 fields, saw 11\nSkipping line 37770: expected 10 fields, saw 11\nSkipping line 38105: expected 10 fields, saw 11\nSkipping line 38275: 
# ...

# %%
df_styles
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
list = ['Flip Flops', 'Water Bottle', 'Vouchers', 'Home Furnishing', 'Sports Accessories', 'Beauty Accessories', 'Wristbands',
       'Umbrellas', 'Perfumes', 'Bath and Body', 'Hair', 'Gloves', 'Eyes', 'Skin', 'Skin Care', 'Cufflinks', 'Lips','Fragrance']

location = "E:\Dataset\fashion-dataset\images"
location_json = "E:\Dataset\fashion-dataset\styles"
import os, glob
for item in list:
    print(item)
    tempdf = df_styles[df_styles.subCategory == item]
    tempdf_indexid = np.array(tempdf.id)
    for i in tempdf_indexid:
        df_styles.drop(df_styles.index[(df_styles.id== i)], axis=0, inplace=True)
       
        try:
            file_name = f'{i}.jpg' 
            path = os.path.join(location, file_name)
            os.remove(path)
            file_name_json = f'{i}.json'
            path2 = os.path.join(location_json, file_name_json)
            os.remove(path2)
        except:
            continue
# Out:
# Flip Flops
# Water Bottle
# Vouchers
# Home Furnishing
# Sports Accessories
# Beauty Accessories
# Wristbands
# Umbrellas
# Perfumes
# Bath and Body
# Hair
# Gloves
# Eyes
# Skin
# Skin Care
# Cufflinks
# Lips
# Fragrance

# %%
df_styles.info
# Out:
# <bound method DataFrame.info of           id gender masterCategory subCategory   articleType baseColour  \
# 0      15970    Men        Apparel     Topwear        Shirts  Navy Blue
# 1      39386    Men        Apparel  Bottomwear         Jeans       Blue
# 2      59263  Women    Accessories     Watches       Watches     Silver
# 3      21379    Men        Apparel  Bottomwear   Track Pants      Black
# 4      53759    Men        Apparel     Topwear       Tshirts       Grey
# ...      ...    ...            ...         ...           ...        ...
# 44417  12544  Women        Apparel     Topwear       Tshirts      Peach
# 44418  42234  Women        Apparel     Topwear          Tops       Blue
# 44419  17036    Men       Footwear       Shoes  Casual Shoes      White
# 44421  18842    Men        Apparel     Topwear       Tshirts       Blue
# 44423  51623  Women    Accessories     Watches       Watches       Pink
#
# ...

# %%
array = df_styles[df_styles.articleType =="Backpacks"]
array
# Out:
#           id  gender masterCategory subCategory articleType baseColour  \
# 145    12732  Unisex    Accessories        Bags   Backpacks      Black
# 203    29319  Unisex    Accessories        Bags   Backpacks        Red
# 326    19920  Unisex    Accessories        Bags   Backpacks      Black
# 385    19316  Unisex    Accessories        Bags   Backpacks       Grey
# 389    19918  Unisex    Accessories        Bags   Backpacks      Black
# ...      ...     ...            ...         ...         ...        ...
# 43851   5228  Unisex    Accessories        Bags   Backpacks       Blue
# 44005   4593  Unisex    Accessories        Bags   Backpacks      Olive
# 44039   5217  Unisex    Accessories        Bags   Backpacks      Brown
# 44289   7123  Unisex    Accessories        Bags   Backpacks     Orange
# 44389   7781  Unisex    Accessories        Bags   Backpacks       Blue
#
#        season    year   usage                        productDisplayName
# ...

# %%
df_styles.to_csv('final.csv')

# %%
for col in df_styles.columns:
    missing_data= df_styles[col].isna().sum()
  
    missing_percent = missing_data/len(df_styles)*100
    print(f'Column: {col}: has {missing_percent}% missing data')
# Out:
# Column: id: has 0.0% missing data
# Column: gender: has 0.0% missing data
# Column: masterCategory: has 0.0% missing data
# Column: subCategory: has 0.0% missing data
# Column: articleType: has 0.0% missing data
# Column: baseColour: has 0.014425504291587525% missing data
# Column: season: has 0.05048926502055634% missing data
# Column: year: has 0.0024042507152645877% missing data
# Column: usage: has 0.35823335657442357% missing data
# Column: productDisplayName: has 0.004808501430529175% missing data

# %%
df_styles
# Out:
#           id gender masterCategory subCategory   articleType baseColour  \
# 0      15970    Men        Apparel     Topwear        Shirts  Navy Blue
# 1      39386    Men        Apparel  Bottomwear         Jeans       Blue
# 2      59263  Women    Accessories     Watches       Watches     Silver
# 3      21379    Men        Apparel  Bottomwear   Track Pants      Black
# 4      53759    Men        Apparel     Topwear       Tshirts       Grey
# ...      ...    ...            ...         ...           ...        ...
# 44417  12544  Women        Apparel     Topwear       Tshirts      Peach
# 44418  42234  Women        Apparel     Topwear          Tops       Blue
# 44419  17036    Men       Footwear       Shoes  Casual Shoes      White
# 44421  18842    Men        Apparel     Topwear       Tshirts       Blue
# 44423  51623  Women    Accessories     Watches       Watches       Pink
#
#        season    year   usage                               productDisplayName
# ...

# %%
index = df_styles[df_styles.masterCategory == 'Apparel']
index = np.array(index.id)

# %%
index = df_styles[df_styles.masterCategory == 'Accessories']
index = np.array(index.id)
print(index)
# Out:
# [59263 29114 30039 ... 10213 40563 51623]

# %% [markdown]
# ## Encode Categorical Data
# Encode independent variable (X)

# %%
Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c881daf1af41> in <module>
# ----> 1 Y
#
# NameError: name 'Y' is not defined

# %%
PATH = "E:\\Dataset\\fashion-dataset"
os.listdir(PATH)
# Out:
# ['images', 'images.csv', 'styles', 'styles.csv']

# %% [markdown]
# # Thêm cột image

# %%
df_styles['image'] = df_styles.apply(lambda row: str(row['id']) + ".jpg", axis=1)

# %%
df_styles
# Out:
#           id gender masterCategory subCategory   articleType baseColour  \
# 0      15970    Men        Apparel     Topwear        Shirts  Navy Blue
# 1      39386    Men        Apparel  Bottomwear         Jeans       Blue
# 2      59263  Women    Accessories     Watches       Watches     Silver
# 3      21379    Men        Apparel  Bottomwear   Track Pants      Black
# 4      53759    Men        Apparel     Topwear       Tshirts       Grey
# ...      ...    ...            ...         ...           ...        ...
# 44417  12544  Women        Apparel     Topwear       Tshirts      Peach
# 44418  42234  Women        Apparel     Topwear          Tops       Blue
# 44419  17036    Men       Footwear       Shoes  Casual Shoes      White
# 44421  18842    Men        Apparel     Topwear       Tshirts       Blue
# 44423  51623  Women    Accessories     Watches       Watches       Pink
#
#        season    year   usage  \
# 0        Fall  2011.0  Casual
# 1      Summer  2012.0  Casual
# ...

# %%
sorted_df = df_styles.groupby([df_styles.articleType]).size().sort_values(ascending= False)
top_classes = sorted_df.nlargest(20)
display(top_classes)
# Out:
# articleType
# Tshirts         7067
# Shirts          3217
# Casual Shoes    2845
# Watches         2542
# Sports Shoes    2036
# Kurtas          1844
# Tops            1762
# Handbags        1759
# Heels           1323
# Sunglasses      1073
# Wallets          936
# Sandals          897
# Briefs           849
# Belts            813
# Backpacks        724
# Socks            686
# Formal Shoes     637
# Jeans            609
# Shorts           547
# Trousers         530
# dtype: int64

# %%
top_classes.plot.bar();

# %%
Tshirt_id = df_styles.image[df_styles.articleType == "Tshirts"]
Tshirt_id = np.array(Tshirt_id)

# %%
Tshirt_id
# Out:
# array(['53759.jpg', '1855.jpg', '7990.jpg', ..., '13496.jpg', '12544.jpg',
#        '18842.jpg'], dtype=object)

# %%
import os
import shutil
def move_file( src, destination, array):
    ##src: nguồn
    ##des: đích
    ##array: mảng chứa item cần di chuyển vd: Tshirt
    #src='E:\\Data\\archive\\fashion-dataset\images'
    src_files = os.listdir(src)
    src_files= np.array(src_files)
    print(type(src_files))
    for item in array:
        for file_name in src_files:
            if item == file_name:
                full_file_name = os.path.join(src, file_name)
                shutil.copy(full_file_name, destination)
        print("Xong item")

# %%
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Tshirt"
move_file(src, des, Tshirt_id )
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
df_styles2 = df_styles

# %%
df_styles2.articleType.value_counts().count()
# Out:
# 113

# %% [markdown]
# ## Di chuyển Shirt

# %%
Shirt_id = df_styles.image[df_styles.articleType == 'Shirts']
Shirt_id = np.array(Shirt_id)

# %%
Shirt_id
# Out:
# array(['15970.jpg', '30805.jpg', '26960.jpg', ..., '6005.jpg',
#        '23031.jpg', '51411.jpg'], dtype=object)

# %%
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Shirt"

# %%
move_file(src, des, Shirt_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Casual_Shoes_id = df_styles.image[df_styles.articleType== 'Casual Shoes']
Casual_Shoes_id = np.array(Casual_Shoes_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Casual_Shoes"

# %%
move_file(src, des, Casual_Shoes_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Tops_id = df_styles.image[df_styles.articleType == 'Tops']
Tops_id = np.array(Tops_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Tops"

# %%
move_file(src, des, Tops_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Watches_id = df_styles.image[df_styles.articleType == 'Watches']
Watches_id = np.array(Watches_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\Watches"

# %%
move_file(src, des, Watches_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Sports_Shoes_id = df_styles.image[df_styles.articleType == 'Sports Shoes']
Sports_Shoes_id = np.array(Sports_Shoes_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Sports_Shoes"

# %%
move_file(src, des, Sports_Shoes_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Kurtas_id = df_styles.image[df_styles.articleType == 'Kurtas']
Kurtas_id = np.array(Kurtas_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Kurtas"

# %%
move_file(src, des, Kurtas_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Handbags_id = df_styles.image[df_styles.articleType == 'Handbags']
Handbags_id = np.array(Handbags_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Handbags"

# %%
move_file(src, des, Handbags_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Heels_id = df_styles.image[df_styles.articleType == 'Heels']
Heels_id = np.array(Heels_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Heels"

# %%
move_file(src, des, Heels_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Sunglasses_id = df_styles.image[df_styles.articleType == 'Sunglasses']
Sunglasses_id = np.array(Sunglasses_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Sunglasses"

# %%
move_file(src, des, Sunglasses_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
# Sunglasses_id = df_styles.image[df_styles.articleType == 'Sunglasses']
# Sunglasses_id = np.array(Sunglasses_id)
# src = 'E:\\Dataset\\fashion-dataset\\images'
# des = 'E:\\Data\\archive\\fashion-dataset\\Data___\\Sunglasses'

# %%
Wallets_id = df_styles.image[df_styles.articleType == 'Wallets']
Wallets_id = np.array(Wallets_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Wallets"

# %%
move_file(src, des, Wallets_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Sandals_id = df_styles.image[df_styles.articleType == 'Sandals']
Sandals_id = np.array(Sandals_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Sandals"

# %%
move_file(src, des, Sandals_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Briefs_id = df_styles.image[df_styles.articleType == 'Briefs']
Briefs_id = np.array(Briefs_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Briefs"

# %%
move_file(src, des, Briefs_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Belts_id = df_styles.image[df_styles.articleType == 'Belts']
Belts_id = np.array(Belts_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Belts"

# %%
move_file(src, des, Belts_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Backpacks_id = df_styles.image[df_styles.articleType == 'Backpacks']
Backpacks_id = np.array(Backpacks_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Backpacks"

# %%
move_file(src, des, Backpacks_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Socks_id = df_styles.image[df_styles.articleType == 'Socks']
Socks_id = np.array(Socks_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Socks"

# %%
move_file(src, des, Socks_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Formal_Shoes_id = df_styles.image[df_styles.articleType == 'Formal Shoes']
Formal_Shoes_id = np.array(Formal_Shoes_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Formal_Shoes"

# %%
move_file(src, des, Formal_Shoes_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Jeans_id = df_styles.image[df_styles.articleType == 'Jeans']
Jeans_id = np.array(Jeans_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Jeans"

# %%
move_file(src, des, Jeans_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Shorts_id = df_styles.image[df_styles.articleType == 'Shorts']
Shorts_id = np.array(Shorts_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Shorts"

# %%
move_file(src, des, Shorts_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %%
Trousers_id = df_styles.image[df_styles.articleType == 'Trousers']
Trousers_id = np.array(Trousers_id)
src = 'E:\\Dataset\\fashion-dataset\\images'
des = "E:\\Dataset\\fashion-dataset\\Divide_data\\Trousers"

# %%
move_file(src, des, Trousers_id)
# Out:
# <class 'numpy.ndarray'>
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# Xong item
# ...

# %% [markdown]
# ## One hot encoding Y

# %%
sorted_df = df_styles.groupby([df_styles.articleType]).size().sort_values(ascending= False)
top_classes = sorted_df.nlargest(20)
top_classes
# Out:
# articleType
# Tshirts         7067
# Shirts          3217
# Casual Shoes    2845
# Watches         2542
# Sports Shoes    2036
# Kurtas          1844
# Tops            1762
# Handbags        1759
# Heels           1323
# Sunglasses      1073
# Wallets          936
# Sandals          897
# Briefs           849
# Belts            813
# Backpacks        724
# Socks            686
# Formal Shoes     637
# Jeans            609
# Shorts           547
# Trousers         530
# dtype: int64

# %%
y = np.array(['Tshirts', 'Shirts', 'Casual Shoes', 'Watches', 'Sports Shoes', 'Kurtas', 'Tops', 'Handbags', 'Heels', 'Sunglasses',
             'Wallets', 'Sandals', 'Briefs', 'Belts', 'Backpacks', 'Socks', 'Formal Shoes', 'Jeans', 'Shorts', 'Trousers'])

# %%
y
# Out:
# array(['Tshirts', 'Shirts', 'Casual Shoes', 'Watches', 'Sports Shoes',
#        'Kurtas', 'Tops', 'Handbags', 'Heels', 'Sunglasses', 'Wallets',
#        'Sandals', 'Briefs', 'Belts', 'Backpacks', 'Socks', 'Formal Shoes',
#        'Jeans', 'Shorts', 'Trousers'], dtype='<U12')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

lableEncoder = LabelEncoder()
y = lableEncoder.fit_transform(y)

# %%
y
# Out:
# array([17, 10,  3, 19, 13,  8, 15,  5,  6, 14, 18,  9,  2,  1,  0, 12,  4,
#         7, 11, 16], dtype=int64)

# %% [markdown]
# # chia dữ liệu

# %%
import cv2
global X
X=[]
global Y
Y=[]

# %%
def applyData(listdir, X, Y):
    percent = 0
    for folder in os.listdir(listdir):
        curr_path = os.path.join(listdir, folder)
        for file in os.listdir(curr_path):
            curr_file = os.path.join(curr_path, file)
            image = cv2.imread(curr_file)
            X.append(image)
            Y.append(folder)
        percent = percent+1
        print(percent + "%")

# %%
print(os.listdir("E:\\Dataset\\fashion-dataset\\Divide_data"))
# Out:
# ['Backpacks', 'Belts', 'Briefs', 'Casual_Shoes', 'Formal_Shoes', 'Handbags', 'Heels', 'Jeans', 'Kurtas', 'Sandals', 'Shirt', 'Shorts', 'Socks', 'Sports_Shoes', 'Sunglasses', 'Tops', 'Trousers', 'Tshirt', 'Wallets', 'Watches']

# %%
listdir = "E:\\Dataset\\fashion-dataset\\Divide_data"
applyData(listdir,X,Y)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-106-a0a32fda9b0f> in <module>
#       1 listdir = "E:\\Dataset\\fashion-dataset\\Divide_data"
# ----> 2 applyData(listdir,X,Y)
#
# <ipython-input-104-9372a717d2ca> in applyData(listdir, X, Y)
#       5         for file in os.listdir(curr_path):
#       6             curr_file = os.path.join(curr_path, file)
# ----> 7             image = cv2.imread(curr_file)
#       8             X.append(image)
#       9             Y.append(folder)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\core\src\alloc.cpp:73: error: (-4:Insufficient memory) Failed to allocate 4665600 bytes in function 'cv::OutOfMemoryError'
